# %% [markdown]
# <a href="https://colab.research.google.com/github/shoeitanaka510-art/python-study/blob/main/Python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello,World")
# Out:
# Hello,World

# %%
isError=False
n=80
if isError==False and n<100:
    print("正解！")
# Out:
# 正解！

# %%
number=int(input("数値を入力してください＞＞"))
if number%2==0:
    print("偶数です")
else:
    print("奇数です")
# Out:
# 数値を入力してください＞＞２０
# 偶数です

# %%
greeting=input("挨拶をどうぞ＞＞")
if greeting=="こんにちは":
    print("ようこそ！")
elif greeting=="景気は？":
    print("ぼちぼちです")
elif greeting=="さようなら":
    print("お元気で！")
else:
    print("どうしました？")
# Out:
# 挨拶をどうぞ＞＞こんにちは
# ようこそ！
